# %% [markdown]
# # Capítulo 2: Sendo Claro e Direto
#
# - [Lição](#lesson)
# - [Exercícios](#exercises)
# - [Playground de Exemplos](#example-playground)
#
# ## Configuração
#
# Execute a célula de configuração a seguir para carregar sua chave de API e estabelecer a função auxiliar `get_completion`.

# %%
# %pip install anthropic --quiet

# Import the hints module from the utils package
import os
import sys
module_path = ".."
sys.path.append(os.path.abspath(module_path))
from utils import hints

# Import python's built-in regular expression library
import re
from anthropic import AnthropicBedrock

# %store -r MODEL_NAME
# %store -r AWS_REGION

client = AnthropicBedrock(aws_region=AWS_REGION)

def get_completion(prompt, system=''):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ],
        system=system
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lição
#
# **Claude responde melhor a instruções claras e diretas.**
#
# Pense em Claude como qualquer outro humano que é novo no trabalho. **Claude não tem contexto** sobre o que fazer além do que você literalmente diz a ele. Assim como quando você instrui um humano pela primeira vez em uma tarefa, quanto mais você explicar exatamente o que quer de maneira direta para Claude, melhor e mais precisa será a resposta de Claude."
#
# Na dúvida, siga a **Regra de Ouro de Prompts Claros**:
# - Mostre seu prompt para um colega ou amigo e peça que eles sigam as instruções para ver se conseguem produzir o resultado que você deseja. Se eles ficarem confusos, Claude ficará confuso.

# %% [markdown]
# ### Exemplos
#
# Vamos pegar uma tarefa como escrever poesia. (Ignore qualquer incompatibilidade de sílabas - LLMs ainda não são ótimos em contar sílabas.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Este haiku é bom o suficiente, mas os usuários podem querer que Claude vá direto para o poema sem o preâmbulo "Aqui está um haiku".
#
# Como conseguimos isso? Nós **pedimos**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Aqui está outro exemplo. Vamos perguntar a Claude quem é o melhor jogador de basquete de todos os tempos. Você pode ver abaixo que, embora Claude liste alguns nomes, **ele não responde com um "melhor" definitivo**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Podemos fazer Claude se decidir e escolher um melhor jogador? Sim! Basta pedir!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Se você quiser experimentar com os prompts da lição sem alterar nenhum conteúdo acima, role até o final do notebook da lição para visitar o [**Playground de Exemplos**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercícios
# - [Exercício 2.1 - Espanhol](#exercise-21---spanish)
# - [Exercício 2.2 - Apenas Um Jogador](#exercise-22---one-player-only)
# - [Exercício 2.3 - Escreva uma História](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercício 2.1 - Espanhol
# Modifique o `SYSTEM_PROMPT` para fazer Claude produzir sua resposta em espanhol.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "[Replace this text]"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Se você quiser uma dica, execute a célula abaixo!

# %%
print(hints.exercise_2_1_hint)

# %% [markdown]
# ### Exercício 2.2 - Apenas Um Jogador
#
# Modifique o `PROMPT` para que Claude não fique indeciso de forma alguma e responda com **APENAS** o nome de um jogador específico, sem **outras palavras ou pontuação**.

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Se você quiser uma dica, execute a célula abaixo!

# %%
print(hints.exercise_2_2_hint)

# %% [markdown]
# ### Exercício 2.3 - Escreva uma História
#
# Modifique o `PROMPT` para que Claude responda com a resposta mais longa que você conseguir obter. Se sua resposta tiver **mais de 800 palavras**, a resposta de Claude será classificada como correta.

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Se você quiser uma dica, execute a célula abaixo!

# %%
print(hints.exercise_2_3_hint)

# %% [markdown]
# ### Parabéns!
#
# Se você resolveu todos os exercícios até este ponto, está pronto para avançar para o próximo capítulo. Bons prompts!

# %% [markdown]
# ---
#
# ## Playground de Exemplos
#
# Esta é uma área para você experimentar livremente com os exemplos de prompts mostrados nesta lição e ajustar os prompts para ver como isso pode afetar as respostas de Claude.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
